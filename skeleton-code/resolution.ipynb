# %%
"""
Question 1.2 a)
"""

""" 
Comment the following claim: “A logistic regression model using pixel values
as features is not as expressive as a multi-layer perceptron using relu activations.
However, training a logistic regression model is easier because it is a convex optimization
problem.” Is this true of false? Justify.

Co-pilot answer: This is true. A logistic regression model is a linear model, and therefore
cannot learn non-linear decision boundaries. A multi-layer perceptron using relu
activations can learn non-linear decision boundaries. However, training a logistic
regression model is easier because it is a convex optimization problem. This means
that there is only one global minimum, and therefore the model will always converge
to the same solution. A multi-layer perceptron using relu activations is not a convex
optimization problem, and therefore there are multiple local minima. This means that
the model may converge to different solutions depending on the initial weights.
"""



"""
"Minha resposta"
Ao utilizar um MLP com ativação ReLU em imagens, conseguimos capturar de forma mais 
eficiente as relações intrínsecas entre os píxeis, como por exemplo padrões. 
No entanto, embora o MLP seja mais expressivo, a sua otimização não é convexa, tornando 
o treino mais difícil quando comparado com a Regressão Logística, que apenas depende dos 
valores lineares dos píxeis. Apesar de esta ser menos expressiva, apresenta 
uma solução convexa, facilitando o processo de treino.
"""
